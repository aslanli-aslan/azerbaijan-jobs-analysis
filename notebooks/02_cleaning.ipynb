# %%
import pandas as pd

from jobanalysis.paths import RAW_DATA, PROCESSED_DATA
from jobanalysis.io import load, save
from jobanalysis.clean import parse_view_count, normalize_category

# %%
df = load(RAW_DATA)

df.head()
# Out:
#       id  ...           fetched_at
# 0  85507  ...  2026-05-04 18:11:57
# 1  85668  ...  2026-05-04 18:11:57
# 2  86834  ...  2026-05-04 18:11:57
# 3  86880  ...  2026-05-04 18:11:57
# 4  87172  ...  2026-05-04 18:11:57
#
# [5 rows x 13 columns]

# %%
df["salary"] = df["salary"].astype(int)
df["salary"] = df["salary"].replace(0, float("nan"))

# %%
df["created_at"] = pd.to_datetime(df["created_at"])
df["deadline_at"] = pd.to_datetime(df["deadline_at"])
df = df.dropna(subset="deadline_at")

# %%
df["company"] = df["company"].replace("Company", None)

# %%
df = parse_view_count(df)

# %%
df = normalize_category(df)

df["category"].value_counts()
# Out:
# category
# Maliyyə xidmətləri                       1164
# Inzibati, Biznes və İdarəetmə            1123
# Mühəndislik                               940
# Pərakəndə satış və müştəri xidmətləri     842
# Marketinq, reklam, çap və nəşriyyat       512
# Komputerləşmə və İKT                      469
# Nəqliyyat, paylama və logistika           463
# Otel, İaşə, Turizm                        356
# Təhsil və Təlim                           275
# Tikinti, Memarlıq və Əmlak                225
# İstehsalat                                132
# Hüquq və Uyğunluq                         122
# Səhiyyə                                   102
# Təhlükəsizlik və Mühafizə                  73
# Ümumi Fəhlə İşləri                         38
# Təmizlik Xidmətləri                        19
# Kənd Təsərrüfatı və Ətraf Mühit            11
# Name: count, dtype: int64

# %%
df = df.drop(columns=["id", "company_id", "url", "fetched_at", "direct_apply"])

# %%
save(df, PROCESSED_DATA)
