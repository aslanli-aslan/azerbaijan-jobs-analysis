# %%
from jobanalysis.paths import RAW_DATA, CLEAN_DATA
from jobanalysis.io import load, save
import jobanalysis.clean as clean

# %%
df = load(RAW_DATA)

df.head()
# Out:
#       id                            title  \
# 0  85507         Maliyyə şöbəsinin müdiri
# 1  85668                General Assistant
# 2  86834     Kabel satışı üzrə mütəxəssis
# 3  86880  Sales and Purchasing Specialist
# 4  87172           Camaşırxana xidmətçisi
#
#                                   company  company_id salary  \
# 0                            AzerMaya MMC       14385      0
# 1  Turan Drilling and Engineering Company        7173      0
# 2                       Baku Cable Goknur        2722      0
# 3               Bureau Veritas Azerbaijan        3068      0
# 4           Baku Marriott Hotel Boulevard        2761      0
#
#                                 category                 created_at  \
# 0                     Maliyyə xidmətləri  2024-09-03T00:00:00+04:00
# 1          Inzibati, Biznes və İdarəetmə  2024-09-04T00:00:00+04:00
# 2  Pərakəndə satış və müştəri xidmətləri  2024-09-16T00:00:00+04:00
# ...

# %%
df = clean.parse_salary(df)

(df["salary"].min(), df["salary"].max())
# Out:
# (np.float64(200.0), np.float64(6000.0))

# %%
df.loc[df["salary"].idxmin()]
# Out:
# id                                                         139409
# title                                Təcrübəçi (Saray / Sumqayıt)
# company                                             Prior Leasing
# company_id                                                   6132
# salary                                                      200.0
# category                            Inzibati, Biznes və İdarəetmə
# created_at                              2026-05-07T00:00:00+04:00
# deadline_at                             2026-06-07T00:00:00+04:00
# view_count                                                    173
# direct_apply                                                    0
# url             https://jobsearch.az/vacancies/prior-leasing-t...
# description     Prior Leasing   satış, lizinq və müştəri xidmə...
# fetched_at                                    2026-05-07 15:53:52
# Name: 2792, dtype: object

# %%
df = clean.parse_dates(df)

# %%
df = clean.parse_company(df)

df["company"].value_counts()
# Out:
# company
# Kontakt Home              35
# Zeytun Pharmaceuticals    34
# Frazex                    25
# Jet Sharing               25
# Capital Logistics LLC     25
#                           ..
# Techart MMC                1
# LN Trading QSC             1
# Kensington                 1
# Mixpromax MMC              1
# Клиника Система            1
# Name: count, Length: 755, dtype: int64

# %%
df = clean.parse_view_count(df)

df["view_count"].describe()
# Out:
# count    2031.000000
# mean      441.608567
# std       317.684880
# min         2.000000
# 25%       211.000000
# 50%       369.000000
# 75%       611.000000
# max      2200.000000
# Name: view_count, dtype: float64

# %%
df = clean.normalize_category(df)

df["category"].value_counts()
# Out:
# category
# Pərakəndə satış və müştəri xidmətləri    353
# Inzibati, Biznes və İdarəetmə            349
# Maliyyə xidmətləri                       333
# Nəqliyyat, paylama və logistika          220
# Otel, İaşə, Turizm                       156
# Marketinq, reklam, çap və nəşriyyat      155
# Mühəndislik                              142
# Tikinti, Memarlıq və Əmlak                82
# Komputerləşmə və İKT                      53
# Təhlükəsizlik və Mühafizə                 36
# İstehsalat                                35
# Səhiyyə                                   33
# Hüquq və Uyğunluq                         27
# Təhsil və Təlim                           25
# Ümumi Fəhlə İşləri                        22
# Təmizlik Xidmətləri                        9
# Kənd Təsərrüfatı və Ətraf Mühit            1
# Name: count, dtype: int64

# %%
df = clean.drop_columns(df)

df.columns
# Out:
# Index(['title', 'company', 'salary', 'category', 'created_at', 'deadline_at',
#        'view_count', 'description'],
#       dtype='str')

# %%
save(df, CLEAN_DATA)
