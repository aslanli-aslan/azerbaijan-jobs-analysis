# %%
from jobanalysis.io import load
from jobanalysis.paths import PROCESSED_DATA
from jobanalysis.extract import extract_experience, extract_education

# %%
df = load(PROCESSED_DATA)

df.head()
df["category"].value_counts()
# Out:
# category
# Maliyyə xidmətləri                       1164
# Inzibati, Biznes və İdarəetmə            1123
# Mühəndislik                               940
# Pərakəndə satış və müştəri xidmətləri     842
# Marketinq, reklam, çap və nəşriyyat       512
# Komputerləşmə və İKT                      469
# Nəqliyyat, paylama və logistika           463
# Otel, İaşə, Turizm                        356
# Təhsil və Təlim                           275
# Tikinti, Memarlıq və Əmlak                225
# İstehsalat                                132
# Hüquq və Uyğunluq                         122
# Səhiyyə                                   102
# Təhlükəsizlik və Mühafizə                  73
# Ümumi Fəhlə İşləri                         38
# Təmizlik Xidmətləri                        19
# Kənd Təsərrüfatı və Ətraf Mühit            11
# Name: count, dtype: int64

# %%
df = extract_experience(df)

# %%
df = extract_education(df)
df["education_level_min"].value_counts()
# Out:
# education_level_min
# Bachelor         3853
# Not Mentioned    2325
# Middle            654
# Master             17
# Not Required       17
# Name: count, dtype: int64
